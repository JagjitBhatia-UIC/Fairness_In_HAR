# %% [markdown]
# # Demo of *Fairness in HAR* Code

# %% [markdown]
# ### Run the following command to make predictions on HMDB test dataset using pre-trained model

# %%
# !python main.py --resume_path results/save_200.pth --model resnet --model_depth 50  --video_path ../../../datasets/HMDB/HMDB_jpgs --annotation_path ../../../datasets/HMDB/HMDB_json/hmdb51.json --result_path results  --n_threads 4 --no_train  --no_val --inference  --inference_batch_size 1 --dataset hmdb51  --n_classes 51
# Out:
# Namespace(accimage=False, annotation_path=PosixPath('/home/jbhati3/datasets/HMDB/HMDB_json/hmdb51.json'), arch='resnet-50', batch_size=128, batchnorm_sync=False, begin_epoch=1, checkpoint=10, colorjitter=False, conv1_t_size=7, conv1_t_stride=1, dampening=0.0, dataset='hmdb51', dist_url='tcp://127.0.0.1:23456', distributed=False, file_type='jpg', ft_begin_module='', inference=True, inference_batch_size=1, inference_crop='center', inference_no_average=False, inference_stride=16, inference_subset='val', input_type='rgb', learning_rate=0.1, lr_scheduler='multistep', manual_seed=1, mean=[0.4345, 0.4051, 0.3775], mean_dataset='kinetics', model='resnet', model_depth=50, momentum=0.9, multistep_milestones=[50, 100, 150], n_classes=51, n_epochs=200, n_input_channels=3, n_pretrain_classes=0, n_threads=4, n_val_samples=3, nesterov=False, no_cuda=False, no_hflip=False, no_max_pool=False, no_mean_norm=False, no_std_norm=False, no_train=True, no_val=True, optimizer='sgd', output_topk=5, overwrite_
# ...

# %% [markdown]
# ### Run the following command to check accuracy of predictions by bucket

# %%
# !python -m util_scripts.eval_accuracy_new ../../../datasets/HMDB/HMDB_json/hmdb51_1.json results/val.json -k 1350
# Out:
# 2021-01-07 12:38:59.120611: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory
# 2021-01-07 12:38:59.120664: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# load ground truth
# 2021-01-07 12:39:00.660768: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2021-01-07 12:39:00.749116: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:19:00.0 name: GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.73GiB deviceMemoryBandwidth: 573.69GiB/s
# 2021-01-07 12:39:00.750219: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 1 with properties:
# ...

# %% [markdown]
# ### Use option --thresh to set confidence $\alpha$ threshold of gender classifier

# %%
# !python -m util_scripts.eval_accuracy_new ../../../datasets/HMDB/HMDB_json/hmdb51_1.json  results/val.json -k 1350 --thresh 75
# Out:
# 2021-01-07 12:50:09.758613: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory
# 2021-01-07 12:50:09.758640: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# load ground truth
# 2021-01-07 12:50:10.529192: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2021-01-07 12:50:10.611125: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:19:00.0 name: GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 68 deviceMemorySize: 10.73GiB deviceMemoryBandwidth: 573.69GiB/s
# 2021-01-07 12:50:10.612205: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 1 with properties:
# ...
